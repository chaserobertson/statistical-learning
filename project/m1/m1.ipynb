# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
small_raw <- read.csv("../rentalbond-data-tla.csv")
head(small_raw)
# Out:
#   Time.Frame Location.Id Location                   Lodged.Bonds Active.Bonds
# 1 1993-02-01 -99         ALL                        9,147        95,583
# 2 1993-02-01  -1         NA                         528          6,285
# 3 1993-02-01   1         Far North District         45           468
# 4 1993-02-01   2         Whangarei District         120          1,248
# 5 1993-02-01   3         Kaipara District           12           108
# 6 1993-02-01  11         Thames-Coromandel District 39           324
#   Closed.Bonds Median.Rent Geometric.Mean.Rent Upper.Quartile.Rent
# 1 7155         150         151                 200
# 2  435         130         128                 165
# 3   24         120         112                 136
# 4  108         120         121                 150
# 5   12         118         113                 121
# 6   21         120         121                 146
#   Lower.Quartile.Rent Log.Std.Dev.Weekly.Rent
# 1 120                 0.43
# ...

# %%
large_raw <- read_csv("../Detailed Quarterly Tenancy.csv")
head(large_raw)
# Out:
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 1007918 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): Time Frame, Dwelling Type, Number Of Beds
# dbl (4): Median Rent, Upper Quartile Rent, Lower Quartile Rent, Log Std Dev ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Time Frame          Location Id Dwelling Type Number Of Beds Total Bonds
# 1 Apr  1 1993 12:00AM -99         ALL           1               2910
# 2 Apr  1 1993 12:00AM -99         ALL           2               8370
# 3 Apr  1 1993 12:00AM -99         ALL           3               8406
# 4 Apr  1 1993 12:00AM -99         ALL           4               1563
# 5 Apr  1 1993 12:00AM -99         ALL           5+               315
# ...

# %%
problems(d2)
spec(d2)
# Out:
#     row     col expected actual
# 1   224222  10  a double 1,156
# 2   230622  10  a double 1,156
# 3   232848  10  a double 1,000
# 4   232858  10  a double 1,100
# 5   239540  10  a double 1,063
# 6   477876  10  a double 1,038
# 7   481930  10  a double 1,038
# 8   484389  10  a double 1,038
# 9   484523  10  a double 1,038
# 10  484600  10  a double 1,038
# 11  484659  10  a double 1,038
# 12  486922  10  a double 1,038
# 13  487035  10  a double 1,038
# 14  487092  10  a double 1,038
# 15  487430  10  a double 1,000
# 16  491430  10  a double 1,000
# 17  493866  10  a double 1,000
# 18  493892  10  a double 1,000
# 19  493918  10  a double 1,000
# 20  493963  10  a double 1,000
# 21  494019  10  a double 1,000
# 22  496234  10  a double 1,000
# 23  496346  10  a double 1,000
# 24  496401  10  a double 1,000
# 25  496733  10  a double 1,125
# 26  498404  10  a double 1,125
# 27  500719  10  a double 1,125
# 28  503125  10  a double 1,125
# 29  503154  10  a double 1,125
# ...

# %%
d2
# Out:
#         Time Frame          Location Id Dwelling Type  Number Of Beds
# 1       Apr  1 1993 12:00AM    -99      ALL            1
# 2       Apr  1 1993 12:00AM    -99      ALL            2
# 3       Apr  1 1993 12:00AM    -99      ALL            3
# 4       Apr  1 1993 12:00AM    -99      ALL            4
# 5       Apr  1 1993 12:00AM    -99      ALL            5+
# 6       Apr  1 1993 12:00AM    -99      ALL            ALL
# 7       Apr  1 1993 12:00AM    -99      ALL            NA
# 8       Apr  1 1993 12:00AM    -99      Flat           1
# 9       Apr  1 1993 12:00AM    -99      Flat           2
# 10      Apr  1 1993 12:00AM    -99      Flat           3
# 11      Apr  1 1993 12:00AM    -99      Flat           4
# 12      Apr  1 1993 12:00AM    -99      Flat           5+
# 13      Apr  1 1993 12:00AM    -99      Flat           ALL
# 14      Apr  1 1993 12:00AM    -99      Flat           NA
# 15      Apr  1 1993 12:00AM    -99      House          1
# ...

# %%
d2dtypes <- d2 %>% filter(`Dwelling Type` == 'Flat')

d2dtypes[order(d2dtypes$`Total Bonds`),]
# Out:
#        Time Frame          Location Id Dwelling Type Number Of Beds Total Bonds
# 1      Apr  1 1993 12:00AM 100700      Flat          2              6
# 2      Apr  1 1993 12:00AM 100700      Flat          ALL            6
# 3      Apr  1 1993 12:00AM 100800      Flat          2              6
# 4      Apr  1 1993 12:00AM 100800      Flat          ALL            6
# 5      Apr  1 1993 12:00AM 106100      Flat          ALL            6
# 6      Apr  1 1993 12:00AM 106900      Flat          ALL            6
# 7      Apr  1 1993 12:00AM 107100      Flat          2              6
# 8      Apr  1 1993 12:00AM 107200      Flat          ALL            6
# 9      Apr  1 1993 12:00AM 107500      Flat          1              6
# 10     Apr  1 1993 12:00AM 108300      Flat          ALL            6
# 11     Apr  1 1993 12:00AM 113000      Flat          ALL            6
# 12     Apr  1 1993 12:00AM 117200      Flat          ALL            6
# ...
